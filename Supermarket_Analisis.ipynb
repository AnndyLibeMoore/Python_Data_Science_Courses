# %% [markdown]
# <a href="https://colab.research.google.com/github/AnndyLibeMoore/Python_My_Learn/blob/main/Supermarket_Analisis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SUPERMARKET_ ANALISIS

# %%
global df_ventas, df_ventas_limpio

# %%
# !python -V
# Out:
# Python 3.10.12

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as  mdates
pd.set_option('display.max_rows',30)
pd.set_option('display.max_columns',30)

# %%
##!python -V
#print('------')
#!pip show Pandas | grep 'Name\|Version'
#print('------')
#pip show Matplotlib | grep 'Name\|Version'

# %% [markdown]
# #En el siguiente mapa podemos ver las regiones y estados de Brásil

# %% [markdown]
# ![Mapa-do-Brasil-3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# La siguiente imagen muestra las 6 ciudades más pobladas de Brásil segun datos del 2021

# %% [markdown]
# ![Ciudades más pobladas 2021.png](data:image/png;base64,...)

# %% [markdown]
# La siguiente es la cantidad de población de las % ciudades más pobladas en el 2019

# %% [markdown]
# ![2019.png](data:image/png;base64,...)

# %% [markdown]
# Veremos la población en el año 2022

# %% [markdown]
# ![2023.png](data:image/png;base64,...)

# %% [markdown]
# Y la siguiente es la previsión al crecimiento en los siguientes 5 años

# %% [markdown]
# ![2028.png](data:image/png;base64,...)

# %% [markdown]
# ### Teniendo en cuenta los datos anteriores y los resultados del analisis de la siguiente base de datos nos permitira saber, si el supermercado ha tenido resultados positivos en el mercado a traves de los años y generar estrategias para mejorar.

# %%
def obtencion_datos():
  global df_ventas, df_ventas_limpio

# %%
df_ventas = pd.read_csv('reporte_ventas.csv')
df_ventas
# Out:
#      fecha_pedido fecha_envio        modo_envio          nombre_cliente  \
# 0      2021-11-09  2021-11-12         Económico         Thiago Silveira
# 1      2021-11-09  2021-11-12         Económico         Thiago Silveira
# 2      2021-06-13  2021-06-17         Económico           Giovanna Lima
# 3      2020-10-12  2020-10-19  Entrega estándar       Ana Júlia da Cruz
# 4      2020-10-12  2020-10-19  Entrega estándar       Ana Júlia da Cruz
# ...           ...         ...               ...                     ...
# 8949   2020-06-19  2020-06-21      Envío rápido          Isabel Almeida
# 8950   2020-06-19  2020-06-21      Envío rápido          Isabel Almeida
# 8951   2021-12-04  2021-12-07      Envío rápido              Isis Alves
# 8952   2021-06-15  2021-06-15          24 horas  Gustavo Henrique Porto
# 8953   2021-09-03  2021-09-05      Envío rápido            Thales Pires
#
#      segmento_cliente          ciudad          estado   region  \
# ...

# %% [markdown]
# ## Parte 2

# %%
df_ventas['fecha_pedido'] = pd.to_datetime(df_ventas['fecha_pedido'],format='%Y-%m-%d')
df_ventas.dtypes
# Out:
# fecha_pedido             datetime64[ns]
# fecha_envio                      object
# modo_envio                       object
# nombre_cliente                   object
# segmento_cliente                 object
# ciudad                           object
# estado                           object
# region                           object
# departamento_producto            object
# tipo_producto                    object
# precio_base                     float64
# precio_unit_sin_desc            float64
# descuento                       float64
# precio_unit_venta               float64
# cantidad_pedido                   int64
# total_venta                     float64
# total_ganancia                  float64
# dtype: object

# %%
df_ventas['fecha_envio'] = pd.to_datetime(df_ventas['fecha_envio'],format='%Y-%m-%d')
df_ventas.dtypes
# Out:
# fecha_pedido             datetime64[ns]
# fecha_envio              datetime64[ns]
# modo_envio                       object
# nombre_cliente                   object
# segmento_cliente                 object
# ciudad                           object
# estado                           object
# region                           object
# departamento_producto            object
# tipo_producto                    object
# precio_base                     float64
# precio_unit_sin_desc            float64
# descuento                       float64
# precio_unit_venta               float64
# cantidad_pedido                   int64
# total_venta                     float64
# total_ganancia                  float64
# dtype: object

# %%
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8954 entries, 0 to 8953
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fecha_pedido           8954 non-null   datetime64[ns]
#  1   fecha_envio            8954 non-null   datetime64[ns]
#  2   modo_envio             8954 non-null   object
#  3   nombre_cliente         8952 non-null   object
#  4   segmento_cliente       8954 non-null   object
#  5   ciudad                 8954 non-null   object
#  6   estado                 8954 non-null   object
#  7   region                 8954 non-null   object
#  8   departamento_producto  8954 non-null   object
#  9   tipo_producto          8954 non-null   object
#  10  precio_base            8954 non-null   float64
#  11  precio_unit_sin_desc   8954 non-null   float64
#  12  descuento              8954 non-null   float64
#  13  precio_unit_venta      8954 non-null   float64
# ...

# %%
df_ventas_limpio = df_ventas.drop_duplicates(inplace= True)

# %%
df_ventas_limpio

# %%
df_ventas['nombre_cliente']
# Out:
# 0         Thiago Silveira
# 1         Thiago Silveira
# 2           Giovanna Lima
# 3       Ana Júlia da Cruz
# 4       Ana Júlia da Cruz
#               ...
# 8935       Enrique Santos
# 8936      Heitor Silveira
# 8937      Heitor Silveira
# 8938        Isabel Araújo
# 8939     Esther Rodrigues
# Name: nombre_cliente, Length: 8939, dtype: object

# %%
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8939 entries, 0 to 8939
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fecha_pedido           8939 non-null   datetime64[ns]
#  1   fecha_envio            8939 non-null   datetime64[ns]
#  2   modo_envio             8939 non-null   object
#  3   nombre_cliente         8937 non-null   object
#  4   segmento_cliente       8939 non-null   object
#  5   ciudad                 8939 non-null   object
#  6   estado                 8939 non-null   object
#  7   region                 8939 non-null   object
#  8   departamento_producto  8939 non-null   object
#  9   tipo_producto          8939 non-null   object
#  10  precio_base            8939 non-null   float64
#  11  precio_unit_sin_desc   8939 non-null   float64
#  12  descuento              8939 non-null   float64
#  13  precio_unit_venta      8939 non-null   float64
# ...

# %%
df_ventas[df_ventas['nombre_cliente'] == 'prueba']
# Out:
#      fecha_pedido fecha_envio        modo_envio nombre_cliente  \
# 12     2022-04-16  2022-04-21  Entrega estándar         prueba
# 2634   2022-11-19  2022-11-25  Entrega estándar         prueba
# 4001   2022-08-15  2022-08-22  Entrega estándar         prueba
# 4037   2021-11-15  2021-11-19  Entrega estándar         prueba
#
#      segmento_cliente              ciudad          estado   region  \
# 12                B2C  São João de Meriti  Rio de Janeiro  Sureste
# 2634              B2B      Ribeirão Pires       São Paulo  Sureste
# 4001              B2C      Rio de Janeiro  Rio de Janeiro  Sureste
# 4037              B2C      Belo Horizonte    Minas Gerais  Sureste
#
#       departamento_producto     tipo_producto  precio_base  \
# 12    Productos de Limpieza  Bolsas de basura        14.54
# 2634                   Ropa          Vestidos        13.27
# 4001                   Ropa        Zapatillas       471.11
# 4037           Electrónicos      Lámparas LED         7.22
#
# ...

# %%
df_ventas['nombre_cliente']
# Out:
# 0         Thiago Silveira
# 1         Thiago Silveira
# 2           Giovanna Lima
# 3       Ana Júlia da Cruz
# 4       Ana Júlia da Cruz
#               ...
# 8935       Enrique Santos
# 8936      Heitor Silveira
# 8937      Heitor Silveira
# 8938        Isabel Araújo
# 8939     Esther Rodrigues
# Name: nombre_cliente, Length: 8939, dtype: object

# %%
df_ventas['nombre_cliente'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 8939 entries, 0 to 8939
# Series name: nombre_cliente
# Non-Null Count  Dtype
# --------------  -----
# 8937 non-null   object
# dtypes: object(1)
# memory usage: 139.7+ KB

# %%
df_ventas_limpio = df_ventas.drop(df_ventas[df_ventas['nombre_cliente'] == 'prueba'].index, inplace = True)
df_ventas_limpio

# %%
df_ventas[df_ventas['nombre_cliente'] == 'prueba']
# Out:
# Empty DataFrame
# Columns: [fecha_pedido, fecha_envio, modo_envio, nombre_cliente, segmento_cliente, ciudad, estado, region, departamento_producto, tipo_producto, precio_base, precio_unit_sin_desc, descuento, precio_unit_venta, cantidad_pedido, total_venta, total_ganancia]
# Index: []

# %%
df_ventas['nombre_cliente'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 8935 entries, 0 to 8939
# Series name: nombre_cliente
# Non-Null Count  Dtype
# --------------  -----
# 8933 non-null   object
# dtypes: object(1)
# memory usage: 139.6+ KB

# %%
df_ventas['nombre_cliente'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8935    False
# 8936    False
# 8937    False
# 8938    False
# 8939    False
# Name: nombre_cliente, Length: 8935, dtype: bool

# %%
df_ventas[df_ventas['nombre_cliente'].isnull()]
# Out:
#      fecha_pedido fecha_envio        modo_envio nombre_cliente  \
# 2495   2022-11-12  2022-11-19  Entrega estándar            NaN
# 5350   2021-12-12  2021-12-12          24 horas            NaN
#
#      segmento_cliente    ciudad  estado        region  departamento_producto  \
# 2495              B2B   Goiânia   Goiás  Centro-Oeste  Productos de Limpieza
# 5350              B2B  Curitiba  Paraná           Sur  Productos de Limpieza
#
#                tipo_producto  precio_base  precio_unit_sin_desc  descuento  \
# 2495        Bolsas de basura        14.54                 19.58        0.1
# 5350  Detergente para platos        21.54                 25.53        0.1
#
#       precio_unit_venta  cantidad_pedido  total_venta  total_ganancia
# 2495              17.62                2        35.24            6.16
# 5350              22.98                2        45.96            2.88

# %%
df_ventas_limpio = df_ventas.dropna(subset = ['nombre_cliente'], inplace = True)
df_ventas_limpio

# %%
df_ventas[df_ventas['nombre_cliente'].isnull()]
# Out:
# Empty DataFrame
# Columns: [fecha_pedido, fecha_envio, modo_envio, nombre_cliente, segmento_cliente, ciudad, estado, region, departamento_producto, tipo_producto, precio_base, precio_unit_sin_desc, descuento, precio_unit_venta, cantidad_pedido, total_venta, total_ganancia]
# Index: []

# %%
ganancia = df_ventas['total_ganancia'] == 0
g1 = df_ventas[ganancia].shape[0]
g1
# Out:
# 60

# %%
#df_ventas.drop(df_ventas[df_ventas['total_ganancia'] == 0].index, inplace=True)

df_ventas_limpio = df_ventas.drop(df_ventas[df_ventas['total_ganancia'] == 0].index)
df_ventas_limpio
# Out:
#      fecha_pedido fecha_envio        modo_envio     nombre_cliente  \
# 0      2021-11-09  2021-11-12         Económico    Thiago Silveira
# 1      2021-11-09  2021-11-12         Económico    Thiago Silveira
# 2      2021-06-13  2021-06-17         Económico      Giovanna Lima
# 3      2020-10-12  2020-10-19  Entrega estándar  Ana Júlia da Cruz
# 4      2020-10-12  2020-10-19  Entrega estándar  Ana Júlia da Cruz
# ...           ...         ...               ...                ...
# 8935   2021-09-30  2021-10-04  Entrega estándar     Enrique Santos
# 8936   2022-11-18  2022-11-22  Entrega estándar    Heitor Silveira
# 8937   2022-11-18  2022-11-22  Entrega estándar    Heitor Silveira
# 8938   2019-01-22  2019-01-24         Económico      Isabel Araújo
# 8939   2022-05-05  2022-05-10         Económico   Esther Rodrigues
#
#      segmento_cliente          ciudad               estado   region  \
# 0                 B2C  Ribeirão Preto            São Paulo  Sureste
# ...

# %%
df_ventas_limpio = df_ventas.drop(df_ventas[df_ventas['total_ganancia'] == 0].index, inplace = True)

# %%
df_ventas_limpio = df_ventas.reset_index(drop=True)
df_ventas_limpio
# Out:
#      fecha_pedido fecha_envio        modo_envio     nombre_cliente  \
# 0      2021-11-09  2021-11-12         Económico    Thiago Silveira
# 1      2021-11-09  2021-11-12         Económico    Thiago Silveira
# 2      2021-06-13  2021-06-17         Económico      Giovanna Lima
# 3      2020-10-12  2020-10-19  Entrega estándar  Ana Júlia da Cruz
# 4      2020-10-12  2020-10-19  Entrega estándar  Ana Júlia da Cruz
# ...           ...         ...               ...                ...
# 8868   2021-09-30  2021-10-04  Entrega estándar     Enrique Santos
# 8869   2022-11-18  2022-11-22  Entrega estándar    Heitor Silveira
# 8870   2022-11-18  2022-11-22  Entrega estándar    Heitor Silveira
# 8871   2019-01-22  2019-01-24         Económico      Isabel Araújo
# 8872   2022-05-05  2022-05-10         Económico   Esther Rodrigues
#
#      segmento_cliente          ciudad               estado   region  \
# 0                 B2C  Ribeirão Preto            São Paulo  Sureste
# ...

# %% [markdown]
# ### En este punto ya hemos trabajado la base datos eliminando datos que no son funcionales como valores duplicados, nulos e incluso registros de ganancia cero, buscado tener los datos más limpios para aplicar estadistica ya a nuestros analisis.

# %% [markdown]
# ## Pregunta 1

# %%
def pregunta_1():
  global df_ventas, df_ventas_limpio

# %%
df_ventas_limpio.to_csv('df_ventas_limpio.csv', sep = ';')

# %%
df_ventas_año = df_ventas_limpio[['fecha_pedido', 'total_venta']].copy()

# %%
df_ventas_año
# Out:
#      fecha_pedido  total_venta
# 0      2021-11-09       890.66
# 1      2021-11-09      2488.59
# 2      2021-06-13        49.72
# 3      2020-10-12      3255.75
# 4      2020-10-12        76.04
# ...           ...          ...
# 8868   2021-09-30       123.22
# 8869   2022-11-18       271.97
# 8870   2022-11-18       700.75
# 8871   2019-01-22        85.83
# 8872   2022-05-05       826.74
#
# [8873 rows x 2 columns]

# %%
df_ventas_año['año'] = df_ventas_año['fecha_pedido'].dt.year

# %%
df_ventas_año.drop('fecha_pedido', axis =1,inplace = True )

# %%
df_ventas_año
# Out:
#       total_venta   año
# 0          890.66  2021
# 1         2488.59  2021
# 2           49.72  2021
# 3         3255.75  2020
# 4           76.04  2020
# ...           ...   ...
# 8868       123.22  2021
# 8869       271.97  2022
# 8870       700.75  2022
# 8871        85.83  2019
# 8872       826.74  2022
#
# [8873 rows x 2 columns]

# %%
df_ventas_año.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8873 entries, 0 to 8872
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   total_venta  8873 non-null   float64
#  1   año          8873 non-null   int64
# dtypes: float64(1), int64(1)
# memory usage: 138.8 KB

# %%
df_ventas_año = df_ventas_año.groupby('año').agg({'total_venta': 'sum'}).reset_index()

# %%
df_ventas_año
# Out:
#     año  total_venta
# 0  2019   1380596.58
# 1  2020   1471121.29
# 2  2021   1855963.32
# 3  2022   2288975.53

# %% [markdown]
# ##2.Visualización

# %%
años =  [2019, 2020, 2021, 2022]
ventas_totales = [1380596.58, 1471121.29, 1855963.32, 2288975.53]

fig, ax = plt.subplots(figsize=(8,4))
ax.bar(años, ventas_totales, color= 'blue', width=0.5, label = 'Venta Totales')

ax.set_title('Ventas Anuales')
ax.set_xlabel('Año')
ax.set_ylabel('Total de Ventas ($)')

for bar in ax.patches:
  valor = bar.get_height()
  qtd =  qtd = "{:,.0f}".format(int(valor))  # Formatea el valor con comas para separar los miles
  ax.text(bar.get_x() + bar.get_width() / 2.0, valor, qtd, ha='center', va='bottom')

ax.set_xticks(años)
ax.set_xticklabels([str(int(a)) for a in años])  # Convierte los años a enteros y los muestra como strings

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)

# Ajusta los márgenes en la parte superior e inferior
ax.margins(y=0.2)

# Oculta los ticks en el eje y
ax.yaxis.set_ticks_position('none')


descripcion = ("El año con mayor ventas fue 2022.\n"
               "teniendo un aumento del 23,33%"
)
ax.text(1.05, 0.5, descripcion, transform=ax.transAxes, fontsize=10, va='center', ha='left',multialignment='left')
# Out:
# Text(1.05, 0.5, 'El año con mayor ventas fue 2022.\nteniendo un aumento del 23,33%')

# %% [markdown]
# ### #Vemos aqui que el año de mayor ventas fue el 2022, mostrando un crecimiento del 23%, auqnue  no ha sido el año con  mayor porcentaje de crecimiento vemos que los números son buenos, asi que es un buen momento para invertir con miras a crecer.

# %%
años = [2019, 2020, 2021, 2022]
ventas_totales = [1380596.58, 1471121.29, 1855963.32, 2288975.53]

fig, ax = plt.subplots(figsize=(8, 4))

# Calcula el porcentaje de crecimiento y almacénalo en una lista
porcentaje_crecimiento = [(ventas_totales[i] - ventas_totales[i-1]) / ventas_totales[i-1] * 100 for i in range(1, len(ventas_totales))]

# Agrega un gráfico de barras para el porcentaje de crecimiento
ax.bar(años[1:], porcentaje_crecimiento, color='green', width=0.5, label='Porcentaje de Crecimiento')

ax.set_title('Porcentaje de Crecimiento de Ventas Anuales')
ax.set_xlabel('Año')
ax.set_ylabel('Porcentaje de Crecimiento (%)')

ax.set_xticks(años)
ax.set_xticklabels([str(int(a)) for a in años])  # Convierte los años a enteros y los muestra como strings

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)

# Ajusta los márgenes en la parte superior e inferior
ax.margins(y=0.2)

# Oculta los ticks en el eje y
ax.yaxis.set_ticks_position('none')

# Añade etiquetas de texto con los valores de porcentaje de crecimiento
for i, bar in enumerate(ax.patches):
    valor = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2.0, valor, f"{valor:.2f}%", ha='center', va='bottom')

descripcion = ("El año con mayor crecimiento fue 2021.\n"
               "teniendo un aumento del 26,16%"
)
ax.text(1.05, 0.5, descripcion, transform=ax.transAxes, fontsize=10, va='center', ha='left',multialignment='left')
# Out:
# Text(1.05, 0.5, 'El año con mayor crecimiento fue 2021.\nteniendo un aumento del 26,16%')

# %% [markdown]
# #Pregunta 2

# %%
def pregunta_2():
  global df_ventas, df_ventas_limpio

# %%
df_ventas_limpio
# Out:
#      fecha_pedido fecha_envio        modo_envio     nombre_cliente  \
# 0      2021-11-09  2021-11-12         Económico    Thiago Silveira
# 1      2021-11-09  2021-11-12         Económico    Thiago Silveira
# 2      2021-06-13  2021-06-17         Económico      Giovanna Lima
# 3      2020-10-12  2020-10-19  Entrega estándar  Ana Júlia da Cruz
# 4      2020-10-12  2020-10-19  Entrega estándar  Ana Júlia da Cruz
# ...           ...         ...               ...                ...
# 8868   2021-09-30  2021-10-04  Entrega estándar     Enrique Santos
# 8869   2022-11-18  2022-11-22  Entrega estándar    Heitor Silveira
# 8870   2022-11-18  2022-11-22  Entrega estándar    Heitor Silveira
# 8871   2019-01-22  2019-01-24         Económico      Isabel Araújo
# 8872   2022-05-05  2022-05-10         Económico   Esther Rodrigues
#
#      segmento_cliente          ciudad               estado   region  \
# 0                 B2C  Ribeirão Preto            São Paulo  Sureste
# ...

# %%
df_top_ganancias = df_ventas_limpio[['tipo_producto', 'total_ganancia']].copy()

# %%
df_top_ganancias
# Out:
#                  tipo_producto  total_ganancia
# 0                    Camisetas           71.26
# 1                        Jeans          373.29
# 2     Toallitas desinfectantes           11.68
# 3                   Zapatillas         -651.15
# 4              Papel higiénico            4.28
# ...                        ...             ...
# 8868               Smartphones           25.88
# 8869               Smartphones           48.96
# 8870         Cámaras digitales           94.60
# 8871                  Vestidos            6.96
# 8872      Ambientador en spray          124.02
#
# [8873 rows x 2 columns]

# %%
df_top_ganancias = df_top_ganancias.groupby('tipo_producto')['total_ganancia'].sum().reset_index(name='total_ganancia_sum')
df_top_ganancias = df_top_ganancias.sort_values(by='total_ganancia_sum', ascending=False)

# %%
df_top_ganancias
# Out:
#                tipo_producto  total_ganancia_sum
# 8                    Laptops            91148.67
# 4          Cámaras digitales            67460.05
# 13               Smartphones            63330.22
# 1           Bolsas de basura            53328.46
# 11              Lámparas LED            53209.52
# 7                      Jeans            41040.84
# 12           Papel higiénico            33941.85
# 0       Ambientador en spray            26784.59
# 15                  Vestidos            20250.42
# 9            Limpiacristales            11254.88
# 10     Limpiador de inodoros             9939.43
# 14  Toallitas desinfectantes             8865.09
# 6      Detergente para ropas             8724.39
# 3           Cepillos de baño             1381.42
# 5     Detergente para platos            -1915.25
# 2                  Camisetas            -5622.34
# 16                Zapatillas           -28877.89

# %%
df_top_ganancias = df_top_ganancias.head(7)

# %%
df_top_ganancias
# Out:
#         tipo_producto  total_ganancia_sum
# 8             Laptops            91148.67
# 4   Cámaras digitales            67460.05
# 13        Smartphones            63330.22
# 1    Bolsas de basura            53328.46
# 11       Lámparas LED            53209.52
# 7               Jeans            41040.84
# 12    Papel higiénico            33941.85

# %% [markdown]
# ### ##2.Visualización

# %% [markdown]
# Para poder invertir necesitamos saber en qué y dónde, la siguiente gráfica nos muestra que los productos que mas ganancia dejan principalmente son del área de electrodomesticos y también tenemos del área de aseo. Teniendo esto en cuenta invertir en aumentar el stock y la variedad de estos productos, tener eventos de descuentos ocasionales e incluir la técnica de venta cruzada cuando hay visitas en estas áreas que ya presentan un buen tráfico de clientes impulsara aún más las ganancias

# %%
tipo_producto = ['Laptops', 'Cámaras digitales', 'Smartphones', 'Bolsa de Basura', 'Lámparas LED', 'Jeans', 'Papel higiénico']
total_ganancia_sum = [91148.67, 67460.05, 63330.22, 53328.46, 53209.52, 41040.84, 33941.85]

tipo_producto, total_ganancia_sum = zip(*sorted(zip(tipo_producto, total_ganancia_sum), key=lambda x: x[1]))


fig, ax = plt.subplots(figsize=(10,6))
colores= ['#0C8040' , '#0077b6' , '#adb5bd']
ax.barh(tipo_producto, total_ganancia_sum, color=colores, align='center')

for i, valor in enumerate(total_ganancia_sum):
    qtd = "${:,.2f}".format(valor)  # Formatea el valor como texto con el símbolo de dólar
    ax.text(valor, i, qtd, ha='left', va='center')

    # Oculta las líneas de los ejes
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.get_xaxis().set_visible(False)

ax.set_title('Top 7 productos con mayor ganancia (2019 - 2022)')

descripcion = ("Podemos ver que los productos de mayor ganancia \n"
               "son del departamento de Electrónicos sin embargo \n"
               "hay productos del departamento de aseo que también \n"
               "tienen muy buena salida y dejan buena ganancia \n"
)

ax.text(1.05, 0.5, descripcion, transform=ax.transAxes, fontsize=10, va='center', ha='left', multialignment='left')
# Out:
# Text(1.05, 0.5, 'Podemos ver que los productos de mayor ganancia \nson del departamento de Electrónicos sin embargo \nhay productos del departamento de aseo que también \ntienen muy buena salida y dejan buena ganancia \n')

# %% [markdown]
# #Pregunta 3

# %%
def pregunta_3():
  global df_ventas, df_ventas_limpio

# %%
df_ventas_año_region = df_ventas_limpio[['fecha_pedido', 'region', 'total_venta']].copy()

# %%
df_ventas_año_region
# Out:
#      fecha_pedido   region  total_venta
# 0      2021-11-09  Sureste       890.66
# 1      2021-11-09  Sureste      2488.59
# 2      2021-06-13  Sureste        49.72
# 3      2020-10-12      Sur      3255.75
# 4      2020-10-12      Sur        76.04
# ...           ...      ...          ...
# 8868   2021-09-30  Sureste       123.22
# 8869   2022-11-18  Noreste       271.97
# 8870   2022-11-18  Noreste       700.75
# 8871   2019-01-22  Noreste        85.83
# 8872   2022-05-05  Noreste       826.74
#
# [8873 rows x 3 columns]

# %%
df_ventas_año_region['año'] = df_ventas_año_region ['fecha_pedido'].dt.year

# %%
df_ventas_año_region
# Out:
#      fecha_pedido   region  total_venta   año
# 0      2021-11-09  Sureste       890.66  2021
# 1      2021-11-09  Sureste      2488.59  2021
# 2      2021-06-13  Sureste        49.72  2021
# 3      2020-10-12      Sur      3255.75  2020
# 4      2020-10-12      Sur        76.04  2020
# ...           ...      ...          ...   ...
# 8868   2021-09-30  Sureste       123.22  2021
# 8869   2022-11-18  Noreste       271.97  2022
# 8870   2022-11-18  Noreste       700.75  2022
# 8871   2019-01-22  Noreste        85.83  2019
# 8872   2022-05-05  Noreste       826.74  2022
#
# [8873 rows x 4 columns]

# %%
df_ventas_año_region = df_ventas_año_region.drop('fecha_pedido', axis = 1)
df_ventas_año_region
# Out:
#        region  total_venta   año
# 0     Sureste       890.66  2021
# 1     Sureste      2488.59  2021
# 2     Sureste        49.72  2021
# 3         Sur      3255.75  2020
# 4         Sur        76.04  2020
# ...       ...          ...   ...
# 8868  Sureste       123.22  2021
# 8869  Noreste       271.97  2022
# 8870  Noreste       700.75  2022
# 8871  Noreste        85.83  2019
# 8872  Noreste       826.74  2022
#
# [8873 rows x 3 columns]

# %%
df_ventas_año_region = pd.crosstab(index=df_ventas_año_region['año'], columns=df_ventas_año_region['region'], values=df_ventas_año_region['total_venta'], aggfunc='sum')

df_ventas_año_region
# Out:
# region  Centro-Oeste    Noreste      Norte        Sur     Sureste
# año
# 2019       114573.48  374940.19  100348.89   60337.46   730396.56
# 2020       146913.30  320512.16  121999.16   91786.25   789910.42
# 2021       207492.19  393922.32  106237.72  132114.48  1016196.61
# 2022       256881.13  593528.76  170311.34  129410.82  1138843.48

# %% [markdown]
# ### ##2.Visualización

# %%
region = ['Centro-Oeste',	'Noreste',	'Norte',	'Sur',	'Sureste']
año = [2019, 2020, 2021, 2022]
colores= [ '#0077b6', '#00b4d8', '#90e0ef', '#adb5bd', '#dee2e6']

ax = df_ventas_año_region.plot(kind='bar', stacked=True, figsize=(15,6), color=colores)


for container in ax.containers:
  labels = [f"${valor:,.2f}" for valor in container.datavalues] #Convertir a texto y adicionar símbolo de $ al inicio
  ax.bar_label(container, label_type='center', labels=labels)


plt.legend(title='Región', loc='upper left', bbox_to_anchor=(1, 1))
ax.tick_params(axis='x', rotation=0)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.get_yaxis().set_visible(False)


ax.set_title('Ventas por Región (2019 - 2022)')

descripcion = ("Mayor venta en la región,\n"
               "Sureste, la más poblada"
)

ax.text(1.05, 0.5, descripcion, transform=ax.transAxes, fontsize=10, va='center', ha='left', multialignment='left')
# Out:
# Text(1.05, 0.5, 'Mayor venta en la región,\nSureste, la más poblada')

# %% [markdown]
# Bien y dónde aumentamos la inversión? La gráfica anterior muestra que las regiones de mayor venta son la Sureste y Sur respectivamente, tomando en cuenta que en estas regiones estan las cápitales más pobladas sabemos ya que las inversiones en stock y variedad deber ser mayores en estas regiones

# %%
df_ventas_año_region_total = df_ventas_año_region.groupby('año').sum()
df_ventas_año_region_total
# Out:
# region  Centro-Oeste    Noreste      Norte        Sur     Sureste
# año
# 2019       114573.48  374940.19  100348.89   60337.46   730396.56
# 2020       146913.30  320512.16  121999.16   91786.25   789910.42
# 2021       207492.19  393922.32  106237.72  132114.48  1016196.61
# 2022       256881.13  593528.76  170311.34  129410.82  1138843.48

# %%
df_crecimiento_region = (df_ventas_año_region_total.pct_change() * 100).round(2)

# Muestra el resultado
print("Porcentaje de Crecimiento por Región y Año:")
print(df_crecimiento_region)
# Out:
# Porcentaje de Crecimiento por Región y Año:
# region  Centro-Oeste  Noreste  Norte    Sur  Sureste
# año
# 2019             NaN      NaN    NaN    NaN      NaN
# 2020           28.23   -14.52  21.57  52.12     8.15
# 2021           41.23    22.90 -12.92  43.94    28.65
# 2022           23.80    50.67  60.31  -2.05    12.07

# %%
# Filtra el DataFrame para excluir el año 2019
df_crecimiento_region_filtrado = df_crecimiento_region.loc[1:]

plt.figure(figsize=(10, 6))

for region in df_crecimiento_region.columns:
    plt.plot(df_crecimiento_region.index, df_crecimiento_region[region], label=region)

plt.title('Porcentaje de Crecimiento por Región y Año')
plt.xlabel('Año')
plt.ylabel('Porcentaje de Crecimiento (%)')
plt.legend()
plt.grid(True)
plt.gca().get_yaxis().set_visible(False)
plt.xticks(df_crecimiento_region.index.astype(int))

descripcion = ("El crecimiento en el Sureste y el Sur,\n"
               "no han tenido mayor relevancia"
)

plt.text(1.05, 0.5, descripcion, transform=plt.gca().transAxes, fontsize=10, va='center', ha='left', multialignment='left')
# Out:
# Text(1.05, 0.5, 'El crecimiento en el Sureste y el Sur,\nno han tenido mayor relevancia')

# %% [markdown]
# Aunque las regiones de mayor venta son la Sus y Sureste si analizamos el porcentaje de crecimento estas se han mantenido en los mismos valores pero la Noreste y la Norte han aumentado lo que puede significar mejores números en un futuro muy cercano, por tanto aumentar la publicidad y el marketing en redes dando ejemplos de gratficacion de clientes puede llevar a un aumento de ventas en estas regiones.

# %% [markdown]
# #Pregunta 4

# %%
def pregunta_4():
  global df_ventas, df_ventas_limpio

# %%
df_modo_envio = df_ventas_limpio[['modo_envio', 'segmento_cliente']].copy()

# %%
df_modo_envio
# Out:
#             modo_envio segmento_cliente
# 0            Económico              B2C
# 1            Económico              B2C
# 2            Económico              B2B
# 3     Entrega estándar              B2C
# 4     Entrega estándar              B2C
# ...                ...              ...
# 8868  Entrega estándar              B2C
# 8869  Entrega estándar              B2B
# 8870  Entrega estándar              B2B
# 8871         Económico              B2C
# 8872         Económico              B2C
#
# [8873 rows x 2 columns]

# %%
df_modo_envio = pd.crosstab(index=df_modo_envio['modo_envio'], columns=df_modo_envio['segmento_cliente']).sort_values("B2B")
df_modo_envio
# Out:
# segmento_cliente   B2B   B2C
# modo_envio
# 24 horas           206   287
# Envío rápido       671   669
# Económico          825   903
# Entrega estándar  2531  2781

# %%
modo_envio = ['24 Horas',	'Envio rápido',	'Económico',	'Entrega estandar']
B2B = [206, 671, 825, 2531]
B2C = [287, 669, 903, 2781]
colores= [ '#0077b6', '#CDDBF3']

fig, ax = plt.subplots(figsize=(10,4))


ax.barh(modo_envio, B2B, color=colores[0])
ax.barh(modo_envio, B2C, left=B2B, color=colores[1])


for container in ax.containers:
  labels = ["{:}".format(valor) for valor in container.datavalues] #Convertir a texto
  ax.bar_label(container, label_type='center', labels=labels)



plt.title('Método de envío más usado (2019 - 2022)')
plt.legend(['B2B','B2C'], loc='lower right')


descripcion = ("El método estandar sigue \n"
               "siendo el preferido"
)

plt.text(1.05, 0.5, descripcion, transform=plt.gca().transAxes, fontsize=10, va='center', ha='left', multialignment='left')
# Out:
# Text(1.05, 0.5, 'El método estandar sigue \nsiendo el preferido')

# %% [markdown]
# El método de envío favorito sigue siendo el estandar lo que lleva a pensar en mejorar y mantener e icluso ampliar la estrategia de envios quiza con empresas de envios que muestren más lugares donde hasta ahora no hemos llegado lo que puede aumentar las posiblidades de llegar a otras regiones

# %% [markdown]
# # Pregunta 5

# %%
def pregunta_4():
  global df_ventas, df_ventas_limpio

# %%
df_ventas_sp = df_ventas_limpio.copy()

# %%
df_ventas_sp
# Out:
#      fecha_pedido fecha_envio        modo_envio     nombre_cliente  \
# 0      2021-11-09  2021-11-12         Económico    Thiago Silveira
# 1      2021-11-09  2021-11-12         Económico    Thiago Silveira
# 2      2021-06-13  2021-06-17         Económico      Giovanna Lima
# 3      2020-10-12  2020-10-19  Entrega estándar  Ana Júlia da Cruz
# 4      2020-10-12  2020-10-19  Entrega estándar  Ana Júlia da Cruz
# ...           ...         ...               ...                ...
# 8868   2021-09-30  2021-10-04  Entrega estándar     Enrique Santos
# 8869   2022-11-18  2022-11-22  Entrega estándar    Heitor Silveira
# 8870   2022-11-18  2022-11-22  Entrega estándar    Heitor Silveira
# 8871   2019-01-22  2019-01-24         Económico      Isabel Araújo
# 8872   2022-05-05  2022-05-10         Económico   Esther Rodrigues
#
#      segmento_cliente          ciudad               estado   region  \
# 0                 B2C  Ribeirão Preto            São Paulo  Sureste
# ...

# %%
df_ventas_sp = df_ventas_sp[df_ventas_sp['estado']== 'São Paulo']
df_ventas_sp
# Out:
#      fecha_pedido fecha_envio        modo_envio           nombre_cliente  \
# 0      2021-11-09  2021-11-12         Económico          Thiago Silveira
# 1      2021-11-09  2021-11-12         Económico          Thiago Silveira
# 15     2019-11-12  2019-11-19  Entrega estándar           Gabriel da Paz
# 37     2022-09-11  2022-09-16  Entrega estándar  Maria Eduarda Rodrigues
# 41     2019-10-21  2019-10-26         Económico               Lara Pinto
# ...           ...         ...               ...                      ...
# 8849   2021-12-06  2021-12-11         Económico               Yuri Viana
# 8853   2020-06-29  2020-07-03  Entrega estándar              Erick Pinto
# 8854   2020-06-29  2020-07-03  Entrega estándar              Erick Pinto
# 8862   2020-09-07  2020-09-10         Económico         Eduarda Teixeira
# 8863   2022-08-04  2022-08-07      Envío rápido      João Pedro Silveira
#
#      segmento_cliente                ciudad     estado   region  \
# ...

# %%
df_ventas_sp = df_ventas_sp[['fecha_pedido', 'total_venta']]
df_ventas_sp
# Out:
#      fecha_pedido  total_venta
# 0      2021-11-09       890.66
# 1      2021-11-09      2488.59
# 15     2019-11-12      2263.98
# 37     2022-09-11       500.36
# 41     2019-10-21       720.64
# ...           ...          ...
# 8849   2021-12-06       372.96
# 8853   2020-06-29       406.50
# 8854   2020-06-29       478.55
# 8862   2020-09-07       292.33
# 8863   2022-08-04        56.15
#
# [2267 rows x 2 columns]

# %%
df_ventas_sp.set_index('fecha_pedido', inplace=True)

# %%
df_ventas_trimestral = df_ventas_sp.resample('Q').agg('sum')
df_ventas_trimestral
# Out:
#               total_venta
# fecha_pedido
# 2019-03-31       39658.47
# 2019-06-30       40968.52
# 2019-09-30      154907.38
# 2019-12-31      144824.39
# 2020-03-31       36132.67
# 2020-06-30       76862.33
# 2020-09-30      129761.66
# 2020-12-31      196423.01
# 2021-03-31       40909.30
# 2021-06-30      107809.08
# 2021-09-30      127724.77
# 2021-12-31      263494.11
# 2022-03-31       65070.91
# 2022-06-30       81651.23
# 2022-09-30      157903.72
# 2022-12-31      324456.79

# %%
df_ventas_trimestral['total_venta'] = (df_ventas_trimestral['total_venta'] / 1000).round(2)
df_ventas_trimestral
# Out:
#               total_venta
# fecha_pedido
# 2019-03-31          39.66
# 2019-06-30          40.97
# 2019-09-30         154.91
# 2019-12-31         144.82
# 2020-03-31          36.13
# 2020-06-30          76.86
# 2020-09-30         129.76
# 2020-12-31         196.42
# 2021-03-31          40.91
# 2021-06-30         107.81
# 2021-09-30         127.72
# 2021-12-31         263.49
# 2022-03-31          65.07
# 2022-06-30          81.65
# 2022-09-30         157.90
# 2022-12-31         324.46

# %%
df_ventas_sp = df_ventas_trimestral.reset_index()
df_ventas_sp
# Out:
#    fecha_pedido  total_venta
# 0    2019-03-31        39.66
# 1    2019-06-30        40.97
# 2    2019-09-30       154.91
# 3    2019-12-31       144.82
# 4    2020-03-31        36.13
# 5    2020-06-30        76.86
# 6    2020-09-30       129.76
# 7    2020-12-31       196.42
# 8    2021-03-31        40.91
# 9    2021-06-30       107.81
# 10   2021-09-30       127.72
# 11   2021-12-31       263.49
# 12   2022-03-31        65.07
# 13   2022-06-30        81.65
# 14   2022-09-30       157.90
# 15   2022-12-31       324.46

# %% [markdown]
# ### ##Pregunta 2
# ### Visualización

# %%
fig, ax = plt.subplots(figsize=(14,4))
puntos_a_marcar = [False, False,False,True,False,False,False,True,False,False,False,True,False,False,False,True]

ejeX = df_ventas_sp['fecha_pedido']
ejeY = df_ventas_sp['total_venta']
ax.plot(ejeX,ejeY,marker="o",markevery=puntos_a_marcar)

x_labels = ["Mar", "Jun", "Set", "Dic"] * 4
ax.set_xticks(df_ventas_sp.fecha_pedido)
ax.set_xticklabels(x_labels, ha="center")

plt.title('Ventas por Trimestre en São Paulo \n de 2019 - 2022 (en miles de dólares)')
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.get_yaxis().set_visible(False)
margen_superior = 0.20
ax.set_ylim(bottom=0, top=(1 + margen_superior) * max(ejeY))


for i in range (len(ejeX)):
  if puntos_a_marcar[i]:
     texto = f"${ejeY.iloc[i]:,.2f}(mil 4° Tri {ejeX.iloc[i].year})"
     ax.text(ejeX.iloc[i], ejeY.iloc[i], texto, ha='left', va='bottom', fontsize=10, color='blue')

# %% [markdown]
# La cápital de Sao Paulo siendo el lugar más poblado presenta el mayor porcentaje de ventas y crecimiento, algo a tomar en cuenta tambien es que cada año el trimestre de mayor ventas es el último, quizas por las navidades, uno de los productos que tambien genera buena rentabilidad fueron los Jeans, teniendo en cuenta el dato anterior el marketing y aumento de stock en ropa podria significar un aumento en estas fechas del último trimestre en esta sección, y seria un buen momento para aplicar uno de los descuentos ocacionales en la tienda y en el marketing en redes que asi atraiga más prospectos.
